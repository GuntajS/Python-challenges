# %%
pwd
# Out:
# 'C:\\Users\\gunta\\OneDrive\\Documents\\Mandeep-US\\Extracurricular\\Python- Tuition 2023'

# %%
f = open('practice.txt','w+')
f.write("This is a test file")

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gunta\\OneDrive\\Documents\\Mandeep-US\\Extracurricular\\Python- Tuition 2023'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Function Practice Exercises.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '2023-07-20-Lambdaexercies.py',
#  '2023-08-19 - 02-Milestone Project 1 - Walkthrough Steps Workbook.ipynb',
#  '2023-08-19 - Tictactoe .ipynb',
#  '2023-09-03 - OOP Python Notes.ipynb',
#  '2023-09-04 - 02-Object Oriented Programming Homework.ipynb',
#  '2023-09-04 - 04-OOP Challenge.ipynb',
#  '2023-09-09 - Errors and Exception handling',
#  '2023-09-09 - Errors and ExceptionsHandling.ipynb',
#  '2023-09-16 - Milestone 2.ipynb',
#  '2023-09-17 - 02-Milestone Project 2 - Walkthrough Steps Workbook.ipynb',
#  '2023-09-24 - 02-Decorators Homework.ipynb',
#  '2023-09-24 - 02-Iterators and Generators Homework.ipynb',
#  '2023-09-24 - Collections module notes.ipynb',
#  '2023-09-24 - Collections-Module.ipynb',
#  'BlackJack',
#  'Complete-Python-3-Bootcamp-master.zip',
#  'guessingGame.py',
#  'kwargsOOP.py',
#  'MyMainPackage',
#  'mymodule.py',
#  'myprogram.py',
#  'one.py',
#  'simple1.py',
#  'test.py',
#  'testfile',
#  'two.py',
#  'Unittestingpractice1.py',
#  'Unittestpractice.py',
#  'Untitled.ipynb',
#  'WarCardGame',
#  '__pycache__']

# %%
import shutil

# %%
shutil.move('two.py','C:\\Users\\gunta\\OneDrive\\Documents\\Mandeep-US\\Extracurricular')
# Out:
# 'C:\\Users\\gunta\\OneDrive\\Documents\\Mandeep-US\\Extracurricular\\two.py'

# %%
import send2trash

# %%
shutil.move("C:\\Users\\gunta\\OneDrive\\Documents\\Mandeep-US\\Extracurricular\\two.py",os.getcwd())
# Out:
# 'C:\\Users\\gunta\\OneDrive\\Documents\\Mandeep-US\\Extracurricular\\Python- Tuition 2023\\two.py'

# %%
send2trash.send2trash('two.py')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Function Practice Exercises.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '2023-07-20-Lambdaexercies.py',
#  '2023-08-19 - 02-Milestone Project 1 - Walkthrough Steps Workbook.ipynb',
#  '2023-08-19 - Tictactoe .ipynb',
#  '2023-09-03 - OOP Python Notes.ipynb',
#  '2023-09-04 - 02-Object Oriented Programming Homework.ipynb',
#  '2023-09-04 - 04-OOP Challenge.ipynb',
#  '2023-09-09 - Errors and Exception handling',
#  '2023-09-09 - Errors and ExceptionsHandling.ipynb',
#  '2023-09-16 - Milestone 2.ipynb',
#  '2023-09-17 - 02-Milestone Project 2 - Walkthrough Steps Workbook.ipynb',
#  '2023-09-24 - 02-Decorators Homework.ipynb',
#  '2023-09-24 - 02-Iterators and Generators Homework.ipynb',
#  '2023-09-24 - Collections module notes.ipynb',
#  '2023-09-24 - Collections-Module.ipynb',
#  'BlackJack',
#  'Complete-Python-3-Bootcamp-master.zip',
#  'guessingGame.py',
#  'kwargsOOP.py',
#  'MyMainPackage',
#  'mymodule.py',
#  'myprogram.py',
#  'one.py',
#  'simple1.py',
#  'test.py',
#  'testfile',
#  'Unittestingpractice1.py',
#  'Unittestpractice.py',
#  'Untitled.ipynb',
#  'WarCardGame',
#  '__pycache__']

# %%
for folder, sub_folders, files in os.walk(os.getcwd()):
    print(f"Currently looking at {folder}")
    print("\n")
    print("The subfolders are: ")
    for sub_fold in sub_folders:
        print(f"\t Subfolder {sub_fold}")
    
    print("\n")
    print("the files are: ")
    for f in files:
        print(f"\t File: {f}")
        
    print("\n")
# Out:
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023
#
#
# The subfolders are:
# 	 Subfolder .ipynb_checkpoints
# 	 Subfolder 2023-09-09 - Errors and Exception handling
# 	 Subfolder BlackJack
# 	 Subfolder MyMainPackage
# 	 Subfolder WarCardGame
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: 03-Function Practice Exercises.ipynb
# 	 File: 08-Functions and Methods Homework.ipynb
# 	 File: 2023-07-20-Lambdaexercies.py
# 	 File: 2023-08-19 - 02-Milestone Project 1 - Walkthrough Steps Workbook.ipynb
# 	 File: 2023-08-19 - Tictactoe .ipynb
# 	 File: 2023-09-03 - OOP Python Notes.ipynb
# 	 File: 2023-09-04 - 02-Object Oriented Programming Homework.ipynb
# 	 File: 2023-09-04 - 04-OOP Challenge.ipynb
# 	 File: 2023-09-09 - Errors and ExceptionsHandling.ipynb
# 	 File: 2023-09-16 - Milestone 2.ipynb
# 	 File: 2023-09-17 - 02-Milestone Project 2 - Walkthrough Steps Workbook.ipynb
# 	 File: 2023-09-24 - 02-Decorators Homework.ipynb
# 	 File: 2023-09-24 - 02-Iterators and Generators Homework.ipynb
# 	 File: 2023-09-24 - Collections module notes.ipynb
# 	 File: 2023-09-24 - Collections-Module.ipynb
# 	 File: Complete-Python-3-Bootcamp-master.zip
# 	 File: guessingGame.py
# 	 File: kwargsOOP.py
# 	 File: mymodule.py
# 	 File: myprogram.py
# 	 File: one.py
# 	 File: simple1.py
# 	 File: test.py
# 	 File: testfile
# 	 File: Unittestingpractice1.py
# 	 File: Unittestpractice.py
# 	 File: Untitled.ipynb
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\.ipynb_checkpoints
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: 03-Function Practice Exercises-checkpoint.ipynb
# 	 File: 08-Functions and Methods Homework-checkpoint.ipynb
# 	 File: 2023-08-19 - Tictactoe -checkpoint.ipynb
# 	 File: 2023-09-03 - OOP Python Notes-checkpoint.ipynb
# 	 File: 2023-09-04 - 02-Object Oriented Programming Homework-checkpoint.ipynb
# 	 File: 2023-09-04 - 04-OOP Challenge-checkpoint.ipynb
# 	 File: 2023-09-09 - Errors and ExceptionsHandling-checkpoint.ipynb
# 	 File: 2023-09-16 - Milestone 2-checkpoint.ipynb
# 	 File: 2023-09-24 - 02-Decorators Homework-checkpoint.ipynb
# 	 File: 2023-09-24 - 02-Iterators and Generators Homework-checkpoint.ipynb
# 	 File: 2023-09-24 - Collections module notes-checkpoint.ipynb
# 	 File: Untitled-checkpoint.ipynb
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\2023-09-09 - Errors and Exception handling
#
#
# The subfolders are:
# 	 Subfolder .ipynb_checkpoints
#
#
# the files are:
# 	 File: 02-Errors and Exceptions Homework.ipynb
# 	 File: 04-Unit Testing.ipynb
# 	 File: cap.py
# 	 File: simple1.py
# 	 File: simple2.py
# 	 File: testfile
# 	 File: test_cap.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\2023-09-09 - Errors and Exception handling\.ipynb_checkpoints
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: 02-Errors and Exceptions Homework-checkpoint.ipynb
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack
#
#
# The subfolders are:
# 	 Subfolder .idea
# 	 Subfolder venv
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: BlackJack.iml
# 	 File: card.py
# 	 File: chips.py
# 	 File: deck.py
# 	 File: hand.py
# 	 File: main.py
# 	 File: player.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\.idea
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: .gitignore
# 	 File: misc.xml
# 	 File: modules.xml
# 	 File: workspace.xml
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv
#
#
# The subfolders are:
# 	 Subfolder Lib
# 	 Subfolder Scripts
#
#
# the files are:
# 	 File: .gitignore
# 	 File: pyvenv.cfg
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib
#
#
# The subfolders are:
# 	 Subfolder site-packages
#
#
# the files are:
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages
#
#
# The subfolders are:
# 	 Subfolder pip
# 	 Subfolder pip-22.3.1.dist-info
# 	 Subfolder pkg_resources
# 	 Subfolder setuptools
# 	 Subfolder setuptools-65.5.1.dist-info
# 	 Subfolder wheel
# 	 Subfolder wheel-0.38.4.dist-info
# 	 Subfolder _distutils_hack
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: distutils-precedence.pth
# 	 File: pip-22.3.1.virtualenv
# 	 File: setuptools-65.5.1.virtualenv
# 	 File: wheel-0.38.4.virtualenv
# 	 File: _virtualenv.pth
# 	 File: _virtualenv.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip
#
#
# The subfolders are:
# 	 Subfolder _internal
# 	 Subfolder _vendor
#
#
# the files are:
# 	 File: py.typed
# 	 File: __init__.py
# 	 File: __main__.py
# 	 File: __pip-runner__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal
#
#
# The subfolders are:
# 	 Subfolder cli
# 	 Subfolder commands
# 	 Subfolder distributions
# 	 Subfolder index
# 	 Subfolder locations
# 	 Subfolder metadata
# 	 Subfolder models
# 	 Subfolder network
# 	 Subfolder operations
# 	 Subfolder req
# 	 Subfolder resolution
# 	 Subfolder utils
# 	 Subfolder vcs
#
#
# the files are:
# 	 File: build_env.py
# 	 File: cache.py
# 	 File: configuration.py
# 	 File: exceptions.py
# 	 File: main.py
# 	 File: pyproject.py
# 	 File: self_outdated_check.py
# 	 File: wheel_builder.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\cli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: autocompletion.py
# 	 File: base_command.py
# 	 File: cmdoptions.py
# 	 File: command_context.py
# 	 File: main.py
# 	 File: main_parser.py
# 	 File: parser.py
# 	 File: progress_bars.py
# 	 File: req_command.py
# 	 File: spinners.py
# 	 File: status_codes.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\commands
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: cache.py
# 	 File: check.py
# 	 File: completion.py
# 	 File: configuration.py
# 	 File: debug.py
# 	 File: download.py
# 	 File: freeze.py
# 	 File: hash.py
# 	 File: help.py
# 	 File: index.py
# 	 File: inspect.py
# 	 File: install.py
# 	 File: list.py
# 	 File: search.py
# 	 File: show.py
# 	 File: uninstall.py
# 	 File: wheel.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\distributions
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: base.py
# 	 File: installed.py
# 	 File: sdist.py
# 	 File: wheel.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\index
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: collector.py
# 	 File: package_finder.py
# 	 File: sources.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\locations
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: base.py
# 	 File: _distutils.py
# 	 File: _sysconfig.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\metadata
#
#
# The subfolders are:
# 	 Subfolder importlib
#
#
# the files are:
# 	 File: base.py
# 	 File: pkg_resources.py
# 	 File: _json.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\metadata\importlib
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _compat.py
# 	 File: _dists.py
# 	 File: _envs.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\models
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: candidate.py
# 	 File: direct_url.py
# 	 File: format_control.py
# 	 File: index.py
# 	 File: installation_report.py
# 	 File: link.py
# 	 File: scheme.py
# 	 File: search_scope.py
# 	 File: selection_prefs.py
# 	 File: target_python.py
# 	 File: wheel.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\network
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: auth.py
# 	 File: cache.py
# 	 File: download.py
# 	 File: lazy_wheel.py
# 	 File: session.py
# 	 File: utils.py
# 	 File: xmlrpc.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\operations
#
#
# The subfolders are:
# 	 Subfolder build
# 	 Subfolder install
#
#
# the files are:
# 	 File: check.py
# 	 File: freeze.py
# 	 File: prepare.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\operations\build
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: build_tracker.py
# 	 File: metadata.py
# 	 File: metadata_editable.py
# 	 File: metadata_legacy.py
# 	 File: wheel.py
# 	 File: wheel_editable.py
# 	 File: wheel_legacy.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\operations\install
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: editable_legacy.py
# 	 File: legacy.py
# 	 File: wheel.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\req
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: constructors.py
# 	 File: req_file.py
# 	 File: req_install.py
# 	 File: req_set.py
# 	 File: req_uninstall.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\resolution
#
#
# The subfolders are:
# 	 Subfolder legacy
# 	 Subfolder resolvelib
#
#
# the files are:
# 	 File: base.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\resolution\legacy
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: resolver.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\resolution\resolvelib
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: base.py
# 	 File: candidates.py
# 	 File: factory.py
# 	 File: found_candidates.py
# 	 File: provider.py
# 	 File: reporter.py
# 	 File: requirements.py
# 	 File: resolver.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\utils
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: appdirs.py
# 	 File: compat.py
# 	 File: compatibility_tags.py
# 	 File: datetime.py
# 	 File: deprecation.py
# 	 File: direct_url_helpers.py
# 	 File: distutils_args.py
# 	 File: egg_link.py
# 	 File: encoding.py
# 	 File: entrypoints.py
# 	 File: filesystem.py
# 	 File: filetypes.py
# 	 File: glibc.py
# 	 File: hashes.py
# 	 File: inject_securetransport.py
# 	 File: logging.py
# 	 File: misc.py
# 	 File: models.py
# 	 File: packaging.py
# 	 File: setuptools_build.py
# 	 File: subprocess.py
# 	 File: temp_dir.py
# 	 File: unpacking.py
# 	 File: urls.py
# 	 File: virtualenv.py
# 	 File: wheel.py
# 	 File: _log.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_internal\vcs
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: bazaar.py
# 	 File: git.py
# 	 File: mercurial.py
# 	 File: subversion.py
# 	 File: versioncontrol.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor
#
#
# The subfolders are:
# 	 Subfolder cachecontrol
# 	 Subfolder certifi
# 	 Subfolder chardet
# 	 Subfolder colorama
# 	 Subfolder distlib
# 	 Subfolder distro
# 	 Subfolder idna
# 	 Subfolder msgpack
# 	 Subfolder packaging
# 	 Subfolder pep517
# 	 Subfolder pkg_resources
# 	 Subfolder platformdirs
# 	 Subfolder pygments
# 	 Subfolder pyparsing
# 	 Subfolder requests
# 	 Subfolder resolvelib
# 	 Subfolder rich
# 	 Subfolder tenacity
# 	 Subfolder tomli
# 	 Subfolder urllib3
# 	 Subfolder webencodings
#
#
# the files are:
# 	 File: six.py
# 	 File: typing_extensions.py
# 	 File: vendor.txt
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\cachecontrol
#
#
# The subfolders are:
# 	 Subfolder caches
#
#
# the files are:
# 	 File: adapter.py
# 	 File: cache.py
# 	 File: compat.py
# 	 File: controller.py
# 	 File: filewrapper.py
# 	 File: heuristics.py
# 	 File: serialize.py
# 	 File: wrapper.py
# 	 File: _cmd.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\cachecontrol\caches
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: file_cache.py
# 	 File: redis_cache.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\certifi
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: cacert.pem
# 	 File: core.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\chardet
#
#
# The subfolders are:
# 	 Subfolder cli
# 	 Subfolder metadata
#
#
# the files are:
# 	 File: big5freq.py
# 	 File: big5prober.py
# 	 File: chardistribution.py
# 	 File: charsetgroupprober.py
# 	 File: charsetprober.py
# 	 File: codingstatemachine.py
# 	 File: cp949prober.py
# 	 File: enums.py
# 	 File: escprober.py
# 	 File: escsm.py
# 	 File: eucjpprober.py
# 	 File: euckrfreq.py
# 	 File: euckrprober.py
# 	 File: euctwfreq.py
# 	 File: euctwprober.py
# 	 File: gb2312freq.py
# 	 File: gb2312prober.py
# 	 File: hebrewprober.py
# 	 File: jisfreq.py
# 	 File: johabfreq.py
# 	 File: johabprober.py
# 	 File: jpcntx.py
# 	 File: langbulgarianmodel.py
# 	 File: langgreekmodel.py
# 	 File: langhebrewmodel.py
# 	 File: langhungarianmodel.py
# 	 File: langrussianmodel.py
# 	 File: langthaimodel.py
# 	 File: langturkishmodel.py
# 	 File: latin1prober.py
# 	 File: mbcharsetprober.py
# 	 File: mbcsgroupprober.py
# 	 File: mbcssm.py
# 	 File: sbcharsetprober.py
# 	 File: sbcsgroupprober.py
# 	 File: sjisprober.py
# 	 File: universaldetector.py
# 	 File: utf1632prober.py
# 	 File: utf8prober.py
# 	 File: version.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\chardet\cli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: chardetect.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\chardet\metadata
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: languages.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\colorama
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: ansi.py
# 	 File: ansitowin32.py
# 	 File: initialise.py
# 	 File: win32.py
# 	 File: winterm.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\distlib
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: compat.py
# 	 File: database.py
# 	 File: index.py
# 	 File: locators.py
# 	 File: manifest.py
# 	 File: markers.py
# 	 File: metadata.py
# 	 File: resources.py
# 	 File: scripts.py
# 	 File: t32.exe
# 	 File: t64-arm.exe
# 	 File: t64.exe
# 	 File: util.py
# 	 File: version.py
# 	 File: w32.exe
# 	 File: w64-arm.exe
# 	 File: w64.exe
# 	 File: wheel.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\distro
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: distro.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\idna
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: codec.py
# 	 File: compat.py
# 	 File: core.py
# 	 File: idnadata.py
# 	 File: intranges.py
# 	 File: package_data.py
# 	 File: uts46data.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\msgpack
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: exceptions.py
# 	 File: ext.py
# 	 File: fallback.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\packaging
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: markers.py
# 	 File: requirements.py
# 	 File: specifiers.py
# 	 File: tags.py
# 	 File: utils.py
# 	 File: version.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: _structures.py
# 	 File: __about__.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pep517
#
#
# The subfolders are:
# 	 Subfolder in_process
#
#
# the files are:
# 	 File: build.py
# 	 File: check.py
# 	 File: colorlog.py
# 	 File: dirtools.py
# 	 File: envbuild.py
# 	 File: meta.py
# 	 File: wrappers.py
# 	 File: _compat.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pep517\in_process
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _in_process.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pkg_resources
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: py31compat.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\platformdirs
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: android.py
# 	 File: api.py
# 	 File: macos.py
# 	 File: unix.py
# 	 File: version.py
# 	 File: windows.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pygments
#
#
# The subfolders are:
# 	 Subfolder filters
# 	 Subfolder formatters
# 	 Subfolder lexers
# 	 Subfolder styles
#
#
# the files are:
# 	 File: cmdline.py
# 	 File: console.py
# 	 File: filter.py
# 	 File: formatter.py
# 	 File: lexer.py
# 	 File: modeline.py
# 	 File: plugin.py
# 	 File: regexopt.py
# 	 File: scanner.py
# 	 File: sphinxext.py
# 	 File: style.py
# 	 File: token.py
# 	 File: unistring.py
# 	 File: util.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pygments\filters
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pygments\formatters
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: bbcode.py
# 	 File: groff.py
# 	 File: html.py
# 	 File: img.py
# 	 File: irc.py
# 	 File: latex.py
# 	 File: other.py
# 	 File: pangomarkup.py
# 	 File: rtf.py
# 	 File: svg.py
# 	 File: terminal.py
# 	 File: terminal256.py
# 	 File: _mapping.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pygments\lexers
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: python.py
# 	 File: _mapping.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pygments\styles
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pyparsing
#
#
# The subfolders are:
# 	 Subfolder diagram
#
#
# the files are:
# 	 File: actions.py
# 	 File: common.py
# 	 File: core.py
# 	 File: exceptions.py
# 	 File: helpers.py
# 	 File: results.py
# 	 File: testing.py
# 	 File: unicode.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\pyparsing\diagram
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\requests
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: adapters.py
# 	 File: api.py
# 	 File: auth.py
# 	 File: certs.py
# 	 File: compat.py
# 	 File: cookies.py
# 	 File: exceptions.py
# 	 File: help.py
# 	 File: hooks.py
# 	 File: models.py
# 	 File: packages.py
# 	 File: sessions.py
# 	 File: status_codes.py
# 	 File: structures.py
# 	 File: utils.py
# 	 File: _internal_utils.py
# 	 File: __init__.py
# 	 File: __version__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\resolvelib
#
#
# The subfolders are:
# 	 Subfolder compat
#
#
# the files are:
# 	 File: providers.py
# 	 File: reporters.py
# 	 File: resolvers.py
# 	 File: structs.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\resolvelib\compat
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: collections_abc.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\rich
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: abc.py
# 	 File: align.py
# 	 File: ansi.py
# 	 File: bar.py
# 	 File: box.py
# 	 File: cells.py
# 	 File: color.py
# 	 File: color_triplet.py
# 	 File: columns.py
# 	 File: console.py
# 	 File: constrain.py
# 	 File: containers.py
# 	 File: control.py
# 	 File: default_styles.py
# 	 File: diagnose.py
# 	 File: emoji.py
# 	 File: errors.py
# 	 File: filesize.py
# 	 File: file_proxy.py
# 	 File: highlighter.py
# 	 File: json.py
# 	 File: jupyter.py
# 	 File: layout.py
# 	 File: live.py
# 	 File: live_render.py
# 	 File: logging.py
# 	 File: markup.py
# 	 File: measure.py
# 	 File: padding.py
# 	 File: pager.py
# 	 File: palette.py
# 	 File: panel.py
# 	 File: pretty.py
# 	 File: progress.py
# 	 File: progress_bar.py
# 	 File: prompt.py
# 	 File: protocol.py
# 	 File: region.py
# 	 File: repr.py
# 	 File: rule.py
# 	 File: scope.py
# 	 File: screen.py
# 	 File: segment.py
# 	 File: spinner.py
# 	 File: status.py
# 	 File: style.py
# 	 File: styled.py
# 	 File: syntax.py
# 	 File: table.py
# 	 File: terminal_theme.py
# 	 File: text.py
# 	 File: theme.py
# 	 File: themes.py
# 	 File: traceback.py
# 	 File: tree.py
# 	 File: _cell_widths.py
# 	 File: _emoji_codes.py
# 	 File: _emoji_replace.py
# 	 File: _export_format.py
# 	 File: _extension.py
# 	 File: _inspect.py
# 	 File: _log_render.py
# 	 File: _loop.py
# 	 File: _palettes.py
# 	 File: _pick.py
# 	 File: _ratio.py
# 	 File: _spinners.py
# 	 File: _stack.py
# 	 File: _timer.py
# 	 File: _win32_console.py
# 	 File: _windows.py
# 	 File: _windows_renderer.py
# 	 File: _wrap.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\tenacity
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: after.py
# 	 File: before.py
# 	 File: before_sleep.py
# 	 File: nap.py
# 	 File: retry.py
# 	 File: stop.py
# 	 File: tornadoweb.py
# 	 File: wait.py
# 	 File: _asyncio.py
# 	 File: _utils.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\tomli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _parser.py
# 	 File: _re.py
# 	 File: _types.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\urllib3
#
#
# The subfolders are:
# 	 Subfolder contrib
# 	 Subfolder packages
# 	 Subfolder util
#
#
# the files are:
# 	 File: connection.py
# 	 File: connectionpool.py
# 	 File: exceptions.py
# 	 File: fields.py
# 	 File: filepost.py
# 	 File: poolmanager.py
# 	 File: request.py
# 	 File: response.py
# 	 File: _collections.py
# 	 File: _version.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\urllib3\contrib
#
#
# The subfolders are:
# 	 Subfolder _securetransport
#
#
# the files are:
# 	 File: appengine.py
# 	 File: ntlmpool.py
# 	 File: pyopenssl.py
# 	 File: securetransport.py
# 	 File: socks.py
# 	 File: _appengine_environ.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\urllib3\contrib\_securetransport
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: bindings.py
# 	 File: low_level.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\urllib3\packages
#
#
# The subfolders are:
# 	 Subfolder backports
#
#
# the files are:
# 	 File: six.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\urllib3\packages\backports
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: makefile.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\urllib3\util
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: connection.py
# 	 File: proxy.py
# 	 File: queue.py
# 	 File: request.py
# 	 File: response.py
# 	 File: retry.py
# 	 File: ssltransport.py
# 	 File: ssl_.py
# 	 File: ssl_match_hostname.py
# 	 File: timeout.py
# 	 File: url.py
# 	 File: wait.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip\_vendor\webencodings
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: labels.py
# 	 File: mklabels.py
# 	 File: tests.py
# 	 File: x_user_defined.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pip-22.3.1.dist-info
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: entry_points.txt
# 	 File: INSTALLER
# 	 File: LICENSE.txt
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources
#
#
# The subfolders are:
# 	 Subfolder extern
# 	 Subfolder _vendor
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\extern
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\extern\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor
#
#
# The subfolders are:
# 	 Subfolder importlib_resources
# 	 Subfolder jaraco
# 	 Subfolder more_itertools
# 	 Subfolder packaging
# 	 Subfolder pyparsing
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: appdirs.py
# 	 File: zipp.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\importlib_resources
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: abc.py
# 	 File: readers.py
# 	 File: simple.py
# 	 File: _adapters.py
# 	 File: _common.py
# 	 File: _compat.py
# 	 File: _itertools.py
# 	 File: _legacy.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\jaraco
#
#
# The subfolders are:
# 	 Subfolder text
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: context.py
# 	 File: functools.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\jaraco\text
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\jaraco\text\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\jaraco\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: context.cpython-311.pyc
# 	 File: functools.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\more_itertools
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: more.py
# 	 File: recipes.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\more_itertools\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: more.cpython-311.pyc
# 	 File: recipes.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\packaging
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: markers.py
# 	 File: requirements.py
# 	 File: specifiers.py
# 	 File: tags.py
# 	 File: utils.py
# 	 File: version.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: _structures.py
# 	 File: __about__.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\packaging\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: markers.cpython-311.pyc
# 	 File: requirements.cpython-311.pyc
# 	 File: specifiers.cpython-311.pyc
# 	 File: tags.cpython-311.pyc
# 	 File: utils.cpython-311.pyc
# 	 File: version.cpython-311.pyc
# 	 File: _manylinux.cpython-311.pyc
# 	 File: _musllinux.cpython-311.pyc
# 	 File: _structures.cpython-311.pyc
# 	 File: __about__.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\pyparsing
#
#
# The subfolders are:
# 	 Subfolder diagram
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: actions.py
# 	 File: common.py
# 	 File: core.py
# 	 File: exceptions.py
# 	 File: helpers.py
# 	 File: results.py
# 	 File: testing.py
# 	 File: unicode.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\pyparsing\diagram
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\pyparsing\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: actions.cpython-311.pyc
# 	 File: common.cpython-311.pyc
# 	 File: core.cpython-311.pyc
# 	 File: exceptions.cpython-311.pyc
# 	 File: helpers.cpython-311.pyc
# 	 File: results.cpython-311.pyc
# 	 File: testing.cpython-311.pyc
# 	 File: unicode.cpython-311.pyc
# 	 File: util.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\_vendor\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: appdirs.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\pkg_resources\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools
#
#
# The subfolders are:
# 	 Subfolder command
# 	 Subfolder config
# 	 Subfolder extern
# 	 Subfolder _distutils
# 	 Subfolder _vendor
#
#
# the files are:
# 	 File: archive_util.py
# 	 File: build_meta.py
# 	 File: cli-32.exe
# 	 File: cli-64.exe
# 	 File: cli-arm64.exe
# 	 File: cli.exe
# 	 File: depends.py
# 	 File: dep_util.py
# 	 File: discovery.py
# 	 File: dist.py
# 	 File: errors.py
# 	 File: extension.py
# 	 File: glob.py
# 	 File: gui-32.exe
# 	 File: gui-64.exe
# 	 File: gui-arm64.exe
# 	 File: gui.exe
# 	 File: installer.py
# 	 File: launch.py
# 	 File: logging.py
# 	 File: monkey.py
# 	 File: msvc.py
# 	 File: namespaces.py
# 	 File: package_index.py
# 	 File: py34compat.py
# 	 File: sandbox.py
# 	 File: script (dev).tmpl
# 	 File: script.tmpl
# 	 File: unicode_utils.py
# 	 File: version.py
# 	 File: wheel.py
# 	 File: windows_support.py
# 	 File: _deprecation_warning.py
# 	 File: _entry_points.py
# 	 File: _imp.py
# 	 File: _importlib.py
# 	 File: _itertools.py
# 	 File: _path.py
# 	 File: _reqs.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\command
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: alias.py
# 	 File: bdist_egg.py
# 	 File: bdist_rpm.py
# 	 File: build.py
# 	 File: build_clib.py
# 	 File: build_ext.py
# 	 File: build_py.py
# 	 File: develop.py
# 	 File: dist_info.py
# 	 File: easy_install.py
# 	 File: editable_wheel.py
# 	 File: egg_info.py
# 	 File: install.py
# 	 File: install_egg_info.py
# 	 File: install_lib.py
# 	 File: install_scripts.py
# 	 File: launcher manifest.xml
# 	 File: py36compat.py
# 	 File: register.py
# 	 File: rotate.py
# 	 File: saveopts.py
# 	 File: sdist.py
# 	 File: setopt.py
# 	 File: test.py
# 	 File: upload.py
# 	 File: upload_docs.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\config
#
#
# The subfolders are:
# 	 Subfolder _validate_pyproject
#
#
# the files are:
# 	 File: expand.py
# 	 File: pyprojecttoml.py
# 	 File: setupcfg.py
# 	 File: _apply_pyprojecttoml.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\config\_validate_pyproject
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: error_reporting.py
# 	 File: extra_validations.py
# 	 File: fastjsonschema_exceptions.py
# 	 File: fastjsonschema_validations.py
# 	 File: formats.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\extern
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_distutils
#
#
# The subfolders are:
# 	 Subfolder command
#
#
# the files are:
# 	 File: archive_util.py
# 	 File: bcppcompiler.py
# 	 File: ccompiler.py
# 	 File: cmd.py
# 	 File: config.py
# 	 File: core.py
# 	 File: cygwinccompiler.py
# 	 File: debug.py
# 	 File: dep_util.py
# 	 File: dir_util.py
# 	 File: dist.py
# 	 File: errors.py
# 	 File: extension.py
# 	 File: fancy_getopt.py
# 	 File: filelist.py
# 	 File: file_util.py
# 	 File: log.py
# 	 File: msvc9compiler.py
# 	 File: msvccompiler.py
# 	 File: py38compat.py
# 	 File: py39compat.py
# 	 File: spawn.py
# 	 File: sysconfig.py
# 	 File: text_file.py
# 	 File: unixccompiler.py
# 	 File: util.py
# 	 File: version.py
# 	 File: versionpredicate.py
# 	 File: _collections.py
# 	 File: _functools.py
# 	 File: _macos_compat.py
# 	 File: _msvccompiler.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_distutils\command
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: bdist.py
# 	 File: bdist_dumb.py
# 	 File: bdist_rpm.py
# 	 File: build.py
# 	 File: build_clib.py
# 	 File: build_ext.py
# 	 File: build_py.py
# 	 File: build_scripts.py
# 	 File: check.py
# 	 File: clean.py
# 	 File: config.py
# 	 File: install.py
# 	 File: install_data.py
# 	 File: install_egg_info.py
# 	 File: install_headers.py
# 	 File: install_lib.py
# 	 File: install_scripts.py
# 	 File: py37compat.py
# 	 File: register.py
# 	 File: sdist.py
# 	 File: upload.py
# 	 File: _framework_compat.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor
#
#
# The subfolders are:
# 	 Subfolder importlib_metadata
# 	 Subfolder importlib_resources
# 	 Subfolder jaraco
# 	 Subfolder more_itertools
# 	 Subfolder packaging
# 	 Subfolder pyparsing
# 	 Subfolder tomli
#
#
# the files are:
# 	 File: ordered_set.py
# 	 File: typing_extensions.py
# 	 File: zipp.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\importlib_metadata
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _adapters.py
# 	 File: _collections.py
# 	 File: _compat.py
# 	 File: _functools.py
# 	 File: _itertools.py
# 	 File: _meta.py
# 	 File: _text.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\importlib_resources
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: abc.py
# 	 File: readers.py
# 	 File: simple.py
# 	 File: _adapters.py
# 	 File: _common.py
# 	 File: _compat.py
# 	 File: _itertools.py
# 	 File: _legacy.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\jaraco
#
#
# The subfolders are:
# 	 Subfolder text
#
#
# the files are:
# 	 File: context.py
# 	 File: functools.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\jaraco\text
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\more_itertools
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: more.py
# 	 File: recipes.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\packaging
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: markers.py
# 	 File: requirements.py
# 	 File: specifiers.py
# 	 File: tags.py
# 	 File: utils.py
# 	 File: version.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: _structures.py
# 	 File: __about__.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\pyparsing
#
#
# The subfolders are:
# 	 Subfolder diagram
#
#
# the files are:
# 	 File: actions.py
# 	 File: common.py
# 	 File: core.py
# 	 File: exceptions.py
# 	 File: helpers.py
# 	 File: results.py
# 	 File: testing.py
# 	 File: unicode.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\pyparsing\diagram
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools\_vendor\tomli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _parser.py
# 	 File: _re.py
# 	 File: _types.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\setuptools-65.5.1.dist-info
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: entry_points.txt
# 	 File: INSTALLER
# 	 File: LICENSE
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\wheel
#
#
# The subfolders are:
# 	 Subfolder cli
# 	 Subfolder vendored
#
#
# the files are:
# 	 File: bdist_wheel.py
# 	 File: macosx_libfile.py
# 	 File: metadata.py
# 	 File: util.py
# 	 File: wheelfile.py
# 	 File: _setuptools_logging.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\wheel\cli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: convert.py
# 	 File: pack.py
# 	 File: unpack.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\wheel\vendored
#
#
# The subfolders are:
# 	 Subfolder packaging
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\wheel\vendored\packaging
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: tags.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\wheel-0.38.4.dist-info
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: entry_points.txt
# 	 File: INSTALLER
# 	 File: LICENSE.txt
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\_distutils_hack
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: override.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\_distutils_hack\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Lib\site-packages\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _virtualenv.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\venv\Scripts
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: activate
# 	 File: activate.bat
# 	 File: activate.fish
# 	 File: activate.nu
# 	 File: activate.ps1
# 	 File: activate_this.py
# 	 File: deactivate.bat
# 	 File: deactivate.nu
# 	 File: pip-3.11.exe
# 	 File: pip.exe
# 	 File: pip3.11.exe
# 	 File: pip3.exe
# 	 File: pydoc.bat
# 	 File: python.exe
# 	 File: pythonw.exe
# 	 File: wheel-3.11.exe
# 	 File: wheel.exe
# 	 File: wheel3.11.exe
# 	 File: wheel3.exe
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\BlackJack\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: card.cpython-311.pyc
# 	 File: chips.cpython-311.pyc
# 	 File: deck.cpython-311.pyc
# 	 File: hand.cpython-311.pyc
# 	 File: player.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\MyMainPackage
#
#
# The subfolders are:
# 	 Subfolder SubPackage
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: some_main_script.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\MyMainPackage\SubPackage
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: mysubscript.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\MyMainPackage\SubPackage\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: mysubscript.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\MyMainPackage\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: some_main_script.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame
#
#
# The subfolders are:
# 	 Subfolder .idea
# 	 Subfolder venv
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: card.py
# 	 File: deck.py
# 	 File: main.py
# 	 File: player.py
# 	 File: WarCardGame.iml
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\.idea
#
#
# The subfolders are:
# 	 Subfolder inspectionProfiles
#
#
# the files are:
# 	 File: .gitignore
# 	 File: misc.xml
# 	 File: modules.xml
# 	 File: workspace.xml
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\.idea\inspectionProfiles
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: Project_Default.xml
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv
#
#
# The subfolders are:
# 	 Subfolder Lib
# 	 Subfolder Scripts
#
#
# the files are:
# 	 File: .gitignore
# 	 File: pyvenv.cfg
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib
#
#
# The subfolders are:
# 	 Subfolder site-packages
#
#
# the files are:
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages
#
#
# The subfolders are:
# 	 Subfolder pip
# 	 Subfolder pip-22.3.1.dist-info
# 	 Subfolder pkg_resources
# 	 Subfolder setuptools
# 	 Subfolder setuptools-65.5.1.dist-info
# 	 Subfolder wheel
# 	 Subfolder wheel-0.38.4.dist-info
# 	 Subfolder _distutils_hack
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: distutils-precedence.pth
# 	 File: pip-22.3.1.virtualenv
# 	 File: setuptools-65.5.1.virtualenv
# 	 File: wheel-0.38.4.virtualenv
# 	 File: _virtualenv.pth
# 	 File: _virtualenv.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pip
#
#
# The subfolders are:
# 	 Subfolder _internal
# 	 Subfolder _vendor
#
#
# the files are:
# 	 File: py.typed
# ...
#
#
# The subfolders are:
# 	 Subfolder text
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: context.py
# 	 File: functools.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\jaraco\text
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\jaraco\text\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\jaraco\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: context.cpython-311.pyc
# 	 File: functools.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\more_itertools
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: more.py
# 	 File: recipes.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\more_itertools\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: more.cpython-311.pyc
# 	 File: recipes.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\packaging
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: markers.py
# 	 File: requirements.py
# 	 File: specifiers.py
# 	 File: tags.py
# 	 File: utils.py
# 	 File: version.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: _structures.py
# 	 File: __about__.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\packaging\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: markers.cpython-311.pyc
# 	 File: requirements.cpython-311.pyc
# 	 File: specifiers.cpython-311.pyc
# 	 File: tags.cpython-311.pyc
# 	 File: utils.cpython-311.pyc
# 	 File: version.cpython-311.pyc
# 	 File: _manylinux.cpython-311.pyc
# 	 File: _musllinux.cpython-311.pyc
# 	 File: _structures.cpython-311.pyc
# 	 File: __about__.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\pyparsing
#
#
# The subfolders are:
# 	 Subfolder diagram
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: actions.py
# 	 File: common.py
# 	 File: core.py
# 	 File: exceptions.py
# 	 File: helpers.py
# 	 File: results.py
# 	 File: testing.py
# 	 File: unicode.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\pyparsing\diagram
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\pyparsing\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: actions.cpython-311.pyc
# 	 File: common.cpython-311.pyc
# 	 File: core.cpython-311.pyc
# 	 File: exceptions.cpython-311.pyc
# 	 File: helpers.cpython-311.pyc
# 	 File: results.cpython-311.pyc
# 	 File: testing.cpython-311.pyc
# 	 File: unicode.cpython-311.pyc
# 	 File: util.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\_vendor\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: appdirs.cpython-311.pyc
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\pkg_resources\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools
#
#
# The subfolders are:
# 	 Subfolder command
# 	 Subfolder config
# 	 Subfolder extern
# 	 Subfolder _distutils
# 	 Subfolder _vendor
#
#
# the files are:
# 	 File: archive_util.py
# 	 File: build_meta.py
# 	 File: cli-32.exe
# 	 File: cli-64.exe
# 	 File: cli-arm64.exe
# 	 File: cli.exe
# 	 File: depends.py
# 	 File: dep_util.py
# 	 File: discovery.py
# 	 File: dist.py
# 	 File: errors.py
# 	 File: extension.py
# 	 File: glob.py
# 	 File: gui-32.exe
# 	 File: gui-64.exe
# 	 File: gui-arm64.exe
# 	 File: gui.exe
# 	 File: installer.py
# 	 File: launch.py
# 	 File: logging.py
# 	 File: monkey.py
# 	 File: msvc.py
# 	 File: namespaces.py
# 	 File: package_index.py
# 	 File: py34compat.py
# 	 File: sandbox.py
# 	 File: script (dev).tmpl
# 	 File: script.tmpl
# 	 File: unicode_utils.py
# 	 File: version.py
# 	 File: wheel.py
# 	 File: windows_support.py
# 	 File: _deprecation_warning.py
# 	 File: _entry_points.py
# 	 File: _imp.py
# 	 File: _importlib.py
# 	 File: _itertools.py
# 	 File: _path.py
# 	 File: _reqs.py
# 	 File: __init__.py
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\command
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: alias.py
# 	 File: bdist_egg.py
# 	 File: bdist_rpm.py
# 	 File: build.py
# 	 File: build_clib.py
# 	 File: build_ext.py
# 	 File: build_py.py
# 	 File: develop.py
# 	 File: dist_info.py
# 	 File: easy_install.py
# 	 File: editable_wheel.py
# 	 File: egg_info.py
# 	 File: install.py
# 	 File: install_egg_info.py
# 	 File: install_lib.py
# 	 File: install_scripts.py
# 	 File: launcher manifest.xml
# 	 File: py36compat.py
# 	 File: register.py
# 	 File: rotate.py
# 	 File: saveopts.py
# 	 File: sdist.py
# 	 File: setopt.py
# 	 File: test.py
# 	 File: upload.py
# 	 File: upload_docs.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\config
#
#
# The subfolders are:
# 	 Subfolder _validate_pyproject
#
#
# the files are:
# 	 File: expand.py
# 	 File: pyprojecttoml.py
# 	 File: setupcfg.py
# 	 File: _apply_pyprojecttoml.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\config\_validate_pyproject
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: error_reporting.py
# 	 File: extra_validations.py
# 	 File: fastjsonschema_exceptions.py
# 	 File: fastjsonschema_validations.py
# 	 File: formats.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\extern
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_distutils
#
#
# The subfolders are:
# 	 Subfolder command
#
#
# the files are:
# 	 File: archive_util.py
# 	 File: bcppcompiler.py
# 	 File: ccompiler.py
# 	 File: cmd.py
# 	 File: config.py
# 	 File: core.py
# 	 File: cygwinccompiler.py
# 	 File: debug.py
# 	 File: dep_util.py
# 	 File: dir_util.py
# 	 File: dist.py
# 	 File: errors.py
# 	 File: extension.py
# 	 File: fancy_getopt.py
# 	 File: filelist.py
# 	 File: file_util.py
# 	 File: log.py
# 	 File: msvc9compiler.py
# 	 File: msvccompiler.py
# 	 File: py38compat.py
# 	 File: py39compat.py
# 	 File: spawn.py
# 	 File: sysconfig.py
# 	 File: text_file.py
# 	 File: unixccompiler.py
# 	 File: util.py
# 	 File: version.py
# 	 File: versionpredicate.py
# 	 File: _collections.py
# 	 File: _functools.py
# 	 File: _macos_compat.py
# 	 File: _msvccompiler.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_distutils\command
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: bdist.py
# 	 File: bdist_dumb.py
# 	 File: bdist_rpm.py
# 	 File: build.py
# 	 File: build_clib.py
# 	 File: build_ext.py
# 	 File: build_py.py
# 	 File: build_scripts.py
# 	 File: check.py
# 	 File: clean.py
# 	 File: config.py
# 	 File: install.py
# 	 File: install_data.py
# 	 File: install_egg_info.py
# 	 File: install_headers.py
# 	 File: install_lib.py
# 	 File: install_scripts.py
# 	 File: py37compat.py
# 	 File: register.py
# 	 File: sdist.py
# 	 File: upload.py
# 	 File: _framework_compat.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor
#
#
# The subfolders are:
# 	 Subfolder importlib_metadata
# 	 Subfolder importlib_resources
# 	 Subfolder jaraco
# 	 Subfolder more_itertools
# 	 Subfolder packaging
# 	 Subfolder pyparsing
# 	 Subfolder tomli
#
#
# the files are:
# 	 File: ordered_set.py
# 	 File: typing_extensions.py
# 	 File: zipp.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\importlib_metadata
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _adapters.py
# 	 File: _collections.py
# 	 File: _compat.py
# 	 File: _functools.py
# 	 File: _itertools.py
# 	 File: _meta.py
# 	 File: _text.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\importlib_resources
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: abc.py
# 	 File: readers.py
# 	 File: simple.py
# 	 File: _adapters.py
# 	 File: _common.py
# 	 File: _compat.py
# 	 File: _itertools.py
# 	 File: _legacy.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\jaraco
#
#
# The subfolders are:
# 	 Subfolder text
#
#
# the files are:
# 	 File: context.py
# 	 File: functools.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\jaraco\text
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\more_itertools
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: more.py
# 	 File: recipes.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\packaging
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: markers.py
# 	 File: requirements.py
# 	 File: specifiers.py
# 	 File: tags.py
# 	 File: utils.py
# 	 File: version.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: _structures.py
# 	 File: __about__.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\pyparsing
#
#
# The subfolders are:
# 	 Subfolder diagram
#
#
# the files are:
# 	 File: actions.py
# 	 File: common.py
# 	 File: core.py
# 	 File: exceptions.py
# 	 File: helpers.py
# 	 File: results.py
# 	 File: testing.py
# 	 File: unicode.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\pyparsing\diagram
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools\_vendor\tomli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _parser.py
# 	 File: _re.py
# 	 File: _types.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\setuptools-65.5.1.dist-info
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: entry_points.txt
# 	 File: INSTALLER
# 	 File: LICENSE
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\wheel
#
#
# The subfolders are:
# 	 Subfolder cli
# 	 Subfolder vendored
#
#
# the files are:
# 	 File: bdist_wheel.py
# 	 File: macosx_libfile.py
# 	 File: metadata.py
# 	 File: util.py
# 	 File: wheelfile.py
# 	 File: _setuptools_logging.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\wheel\cli
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: convert.py
# 	 File: pack.py
# 	 File: unpack.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\wheel\vendored
#
#
# The subfolders are:
# 	 Subfolder packaging
#
#
# the files are:
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\wheel\vendored\packaging
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: tags.py
# 	 File: _manylinux.py
# 	 File: _musllinux.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\wheel-0.38.4.dist-info
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: entry_points.txt
# 	 File: INSTALLER
# 	 File: LICENSE.txt
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\_distutils_hack
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# the files are:
# 	 File: override.py
# 	 File: __init__.py
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\_distutils_hack\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: __init__.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Lib\site-packages\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: _virtualenv.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\venv\Scripts
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: activate
# 	 File: activate.bat
# 	 File: activate.fish
# 	 File: activate.nu
# 	 File: activate.ps1
# 	 File: activate_this.py
# 	 File: deactivate.bat
# 	 File: deactivate.nu
# 	 File: pip-3.11.exe
# 	 File: pip.exe
# 	 File: pip3.11.exe
# 	 File: pip3.exe
# 	 File: pydoc.bat
# 	 File: python.exe
# 	 File: pythonw.exe
# 	 File: wheel-3.11.exe
# 	 File: wheel.exe
# 	 File: wheel3.11.exe
# 	 File: wheel3.exe
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\WarCardGame\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: card.cpython-311.pyc
# 	 File: deck.cpython-311.pyc
# 	 File: main.cpython-311.pyc
# 	 File: player.cpython-311.pyc
#
#
# Currently looking at C:\Users\gunta\OneDrive\Documents\Mandeep-US\Extracurricular\Python- Tuition 2023\__pycache__
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: mymodule.cpython-311.pyc
# 	 File: one.cpython-311.pyc
# 	 File: Unittestpractice.cpython-311.pyc
