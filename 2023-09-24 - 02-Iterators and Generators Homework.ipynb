# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Iterators and Generators Homework
#
# ### Problem 1
#
# Create a generator that generates the squares of numbers up to some number N.

# %%
def gensquares(N):
    
    for n in range(N):
        yield n**2

# %%
for x in gensquares(10):
    print(x)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ### Problem 2
#
# Create a generator that yields "n" random numbers between a low and high number (that are inputs). <br>Note: Use the random library. For example:

# %%
import random

random.randint(1,10)
# Out:
# 4

# %%
def rand_num(low,high,n):
    
    for i in range(n):
        yield random.randint(low,high)

# %%
for num in rand_num(1,10,12):
    print(num)
# Out:
# 6
# 3
# 7
# 4
# 7
# 3
# 9
# 5
# 1
# 1
# 6
# 10

# %% [markdown]
# ### Problem 3
#
# Use the iter() function to convert the string below into an iterator:

# %%
s = 'hello'

s_iter = iter(s)

#code here

# %% [markdown]
# ### Problem 4
# Explain a use case for a generator using a yield statement where you would not want to use a normal function with a return statement.<br><br><br><br><br><br>
# where there is a requirement of large amount of values, for example iterating through number 1 to a million, the normal function with return would be inefficient in memory

# %% [markdown]
# ### Extra Credit!
# Can you explain what *gencomp* is in the code below? (Note: We never covered this in lecture! You will have to do some Googling/Stack Overflowing!)

# %%
my_list = [1,2,3,4,5]

gencomp = (item for item in my_list if item > 3) #generator expression 

for item in gencomp:
    print(item)
# Out:
# 4
# 5

# %% [markdown]
# Hint: Google *generator comprehension*!![image.png](attachment:image.png)
#
#
# # Great Job!
